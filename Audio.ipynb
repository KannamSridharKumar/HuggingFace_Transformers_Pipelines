# %%
# %load_ext nb_black

# %%
from transformers import pipeline
from datasets import load_dataset
import sounddevice as sd
import soundfile as sf

# %% [markdown]
# <br />  <font size="+2">1. Audio Classification</font> <br /> <br />
# - Predicts the class of a raw waveform or an audio file.
# - Command recognition or keyword spotting classifies utterances into a predefined set of commands.

# %%
classifier = pipeline(
    task="audio-classification", model="superb/wav2vec2-base-superb-ks"
)

#'yes', 'no', 'up', 'down', 'left', 'right', 'on', 'off', 'stop', 'go', 'unknown', 'silence'
# Out:
# /Users/sridharkannam/opt/anaconda3/envs/py11/lib/python3.8/site-packages/transformers/configuration_utils.py:379: UserWarning: Passing `gradient_checkpointing` to a config initialization is deprecated and will be removed in v5 Transformers. Using `model.gradient_checkpointing_enable()` instead, or if you are using the `Trainer` API, pass `gradient_checkpointing=True` in your `TrainingArguments`.
#   warnings.warn(

# %%
classifier("https://huggingface.co/datasets/Narsil/asr_dummy/resolve/main/1.flac")
# Out:
# [{'score': 0.9972336888313293, 'label': '_unknown_'},
#  {'score': 0.0019911823328584433, 'label': 'left'},
#  {'score': 0.0003051071835216135, 'label': 'yes'},
#  {'score': 0.00021083909086883068, 'label': 'down'},
#  {'score': 0.0001140652530011721, 'label': 'stop'}]

# %%
dataset = load_dataset("anton-l/superb_demo", "ks", split="test")
classifier(dataset[0]["file"], top_k=2)
# Out:
# Found cached dataset superb_demo (/Users/sridharkannam/.cache/huggingface/datasets/anton-l___superb_demo/ks/1.9.0/77d23894ff429329a7fe80f9007cabb0deec321316f8dda1a1e9d10ffa089d08)
# [W NNPACK.cpp:64] Could not initialize NNPACK! Reason: Unsupported hardware.
# [{'score': 0.9999943971633911, 'label': '_silence_'},
#  {'score': 2.49855179390579e-06, 'label': 'left'}]

# %%
for data in dataset:
    print(classifier(data["file"], top_k=1))
# Out:
# [{'score': 0.9999943971633911, 'label': '_silence_'}]
# [{'score': 0.9844678044319153, 'label': '_unknown_'}]
# [{'score': 0.9983683228492737, 'label': '_unknown_'}]
# [{'score': 0.9946255087852478, 'label': '_unknown_'}]
# [{'score': 0.9979941844940186, 'label': 'down'}]
# [{'score': 0.9999951124191284, 'label': 'go'}]
# [{'score': 0.2914532721042633, 'label': 'up'}]
# [{'score': 0.9973770380020142, 'label': 'no'}]

# %%
# Extract data and sampling rate from file
data, fs = sf.read(dataset[-5]["file"], dtype="float32")
sd.play(data, fs)

# %%
dataset = load_dataset("anton-l/superb_demo", "ks", split="test")
dataset[5]
# Out:
# Found cached dataset superb_demo (/Users/sridharkannam/.cache/huggingface/datasets/anton-l___superb_demo/ks/1.9.0/77d23894ff429329a7fe80f9007cabb0deec321316f8dda1a1e9d10ffa089d08)
# {'file': '/Users/sridharkannam/.cache/huggingface/datasets/downloads/extracted/a825fceea0ebca08b8ce8f05031914994ed6671301d2851938b965f956fd1646/go/0c40e715_nohash_0.wav',
#  'audio': {'path': '/Users/sridharkannam/.cache/huggingface/datasets/downloads/extracted/a825fceea0ebca08b8ce8f05031914994ed6671301d2851938b965f956fd1646/go/0c40e715_nohash_0.wav',
#   'array': array([-0.00985718, -0.02383423, -0.02752686, ..., -0.02755737,
#          -0.01998901, -0.01361084], dtype=float32),
#   'sampling_rate': 16000},
#  'label': 9}

# %% [markdown]
# <br />  <font size="+2">2. Speech Recognition</font> <br /> <br />
#
# Extract spoken text contained within audio.

# %%
transcriber = pipeline(model="openai/whisper-base")

# %%
transcriber("https://huggingface.co/datasets/Narsil/asr_dummy/resolve/main/1.flac")
# Out:
# /Users/sridharkannam/opt/anaconda3/envs/py11/lib/python3.8/site-packages/transformers/generation/utils.py:1288: UserWarning: Using `max_length`'s default (448) to control the generation length. This behaviour is deprecated and will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# {'text': ' He hoped there would be stew for dinner, turnips and carrots and bruised potatoes and fat mutton pieces to be ladled out in thick, peppered flour-fatten sauce.'}

# %%
transcriber(
    "https://huggingface.co/datasets/Narsil/asr_dummy/resolve/main/1.flac",
    return_timestamps=True,
)
# utterance level timestamps
# Out:
# /Users/sridharkannam/opt/anaconda3/envs/py11/lib/python3.8/site-packages/transformers/generation/utils.py:1288: UserWarning: Using `max_length`'s default (448) to control the generation length. This behaviour is deprecated and will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# {'text': ' He hoped there would be stew for dinner, turnips and carrots and bruised potatoes and fat mutton pieces to be ladled out in thick, peppered flour-fatten sauce.',
#  'chunks': [{'timestamp': (0.0, 5.6),
#    'text': ' He hoped there would be stew for dinner, turnips and carrots and bruised potatoes and fat'},
#   {'timestamp': (5.6, 10.12),
#    'text': ' mutton pieces to be ladled out in thick, peppered flour-fatten sauce.'}]}

# %% [markdown]
# <br />  <font size="+2">3. Zero shot classification</font> <br /> <br />

# %%
classifier = pipeline(
    task="zero-shot-audio-classification", model="laion/clap-htsat-unfused"
)

# %%
dataset = load_dataset("ashraq/esc50")
dataset["train"]["audio"]
# Out:
# Found cached dataset parquet (/Users/sridharkannam/.cache/huggingface/datasets/ashraq___parquet/ashraq--esc50-1000c3b73cc1500f/0.0.0/2a3b91fbd88a2c90d1dbbb32b460cf621d31bd5b05b934492fdef7d8d6f236ec)
#   0%|          | 0/1 [00:00<?, ?it/s]
# [{'path': None,
#   'array': array([0., 0., 0., ..., 0., 0., 0.]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([-0.01184082, -0.10336304, -0.14141846, ...,  0.06985474,
#           0.04049683,  0.00274658]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([-0.00695801, -0.01251221, -0.01126099, ...,  0.215271  ,
#          -0.00875854, -0.28903198]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([0.53897095, 0.39627075, 0.26739502, ..., 0.09729004, 0.11227417,
#          0.07983398]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([-0.00036621, -0.0007019 , -0.00079346, ...,  0.00317383,
#           0.00222778,  0.00158691]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([-9.46044922e-04, -6.71386719e-04, -6.10351562e-05, ...,
#          -2.13623047e-03, -2.62451172e-03, -3.17382812e-03]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([0.00012207, 0.00018311, 0.00012207, ..., 0.        , 0.        ,
#          0.        ]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([0.00170898, 0.00177002, 0.00177002, ..., 0.00088501, 0.00021362,
#          0.        ]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([-0.44656372, -0.47012329, -0.4803772 , ..., -0.06384277,
#          -0.05136108, -0.04431152]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([3.05175781e-05, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([3.05175781e-05, 3.05175781e-05, 3.05175781e-05, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([-6.10351562e-05, -6.10351562e-05,  6.10351562e-05, ...,
#          -1.95922852e-01, -1.72943115e-01, -9.98229980e-02]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([-0.0718689 , -0.06530762, -0.07348633, ...,  0.        ,
#           0.        ,  0.        ]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([ 0.01879883, -0.01760864, -0.05441284, ..., -0.02911377,
#          -0.02935791, -0.0296936 ]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([-0.00256348, -0.00112915,  0.00012207, ...,  0.        ,
#           0.        ,  0.        ]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([-0.25811768, -0.26950073, -0.21060181, ..., -0.52600098,
#          -0.65093994, -0.71273804]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([0.04312134, 0.04193115, 0.04037476, ..., 0.0151062 , 0.01547241,
#          0.01589966]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([0
),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([-0.00167847, -0.00561523, -0.00836182, ..., -0.00057983,
#          -0.00061035, -0.00057983]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([-0.03204346, -0.037323  , -0.04345703, ..., -0.05651855,
#          -0.0451355 , -0.02975464]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([-0.00045776, -0.00045776, -0.00045776, ..., -0.00036621,
#          -0.00045776, -0.00045776]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([-0.02233887, -0.0083313 ,  0.00616455, ..., -0.01513672,
#          -0.01519775, -0.01565552]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([-0.02679443, -0.02285767, -0.01712036, ...,  0.        ,
#           0.        ,  0.        ]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([-0.00085449, -0.0007019 , -0.00048828, ...,  0.        ,
#           0.        ,  0.        ]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([-0.04125977, -0.0760498 , -0.0826416 , ...,  0.        ,
#           0.        ,  0.        ]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([-0.0663147 , -0.06793213, -0.06906128, ...,  0.00830078,
#           0.00830078,  0.00869751]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([ 0.09442139,  0.09829712,  0.10177612, ..., -0.01895142,
#          -0.01907349, -0.0196228 ]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([0.00079346, 0.00112915, 0.00234985, ..., 0.        , 0.        ,
#          0.        ]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([0.0194397 , 0.02713013, 0.03198242, ..., 0.        , 0.        ,
#          0.        ]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([-0.00579834, -0.00588989, -0.00653076, ...,  0.04611206,
#           0.04083252,  0.03433228]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([0.02709961, 0.02160645, 0.03262329, ..., 0.02642822, 0.03097534,
#          0.03973389]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([-0.05084229, -0.07290649, -0.11245728, ..., -0.04550171,
#          -0.04641724, -0.04602051]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([-0.03994751, -0.04049683, -0.04077148, ...,  0.084198  ,
#           0.08001709,  0.07495117]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([-0.00027466, -0.00018311, -0.00024414, ...,  0.        ,
#           0.        ,  0.        ]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([-0.0015564 , -0.00738525, -0.01028442, ...,  0.05062866,
#           0.04940796,  0.04800415]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([ 0.00537109,  0.0057373 ,  0.00543213, ..., -0.04064941,
#          -0.0642395 , -0.04397583]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([0.01693726, 0.01654053, 0.01672363, ..., 0.00357056, 0.00354004,
#          0.00375366]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([-0.02310181, -0.02322388, -0.02322388, ...,  0.06970215,
#           0.06549072,  0.05612183]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([ 0.06512451,  0.17935181,  0.27008057, ..., -0.02163696,
#          -0.0708313 , -0.05551147]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([-0.00152588, -0.00201416, -0.00112915, ...,  0.00076294,
#          -0.00265503, -0.00653076]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([0.04742432, 0.0451355 , 0.0447998 , ..., 0.        , 0.        ,
#          0.        ]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([0.07281494, 0.08346558, 0.05780029, ..., 0.03671265, 0.02578735,
#          0.02609253]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([0., 0., 0., ..., 0., 0., 0.]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([-0.08203125, -0.09844971, -0.09368896, ...,  0.        ,
#           0.        ,  0.        ]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([ 0.        ,  0.        ,  0.        , ...,  0.00057983,
#           0.0005188 , -0.00021362]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([-0.01409912, -0.01672363, -0.01904297, ..., -0.01528931,
#          -0.00967407, -0.00549316]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([-0.05453491, -0.05841064, -0.05490112, ...,  0.03756714,
#           0.04403687,  0.05541992]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([-3.66210938e-04, -5.18798828e-04, -1.31225586e-03, ...,
#          -1.52587891e-04, -1.83105469e-04, -9.15527344e-05]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([ 0.00045776, -0.01287842, -0.00860596, ..., -0.03143311,
#          -0.02261353,  0.04345703]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([-0.02438354,  0.02487183,  0.03076172, ...,  0.00192261,
#           0.02905273,  0.02627563]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([0.00811768, 0.00915527, 0.00643921, ..., 0.        , 0.        ,
#          0.        ]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([-0.27566528, -0.26690674, -0.25796509, ...,  0.        ,
#           0.        ,  0.        ]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([ 0.00961304,  0.0017395 , -0.01586914, ...,  0.        ,
#           0.        ,  0.        ]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([0.00119019, 0.00131226, 0.0012207 , ..., 0.        , 0.        ,
#          0.        ]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([-0.00268555,  0.04489136,  0.04202271, ..., -0.00125122,
#          -0.00897217, -0.00772095]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([-0.1015625 , -0.00360107,  0.03939819, ..., -0.0078125 ,
#           0.06433105,  0.06860352]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([ 0.11932373,  0.01675415, -0.1144104 , ...,  0.04013062,
#           0.06130981,  0.01412964]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([1.22070312e-04, 9.15527344e-05, 9.15527344e-05, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([ 0.00216675,  0.00271606,  0.00268555, ..., -0.01992798,
#          -0.0227356 , -0.01733398]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([-0.47647095, -0.52462769, -0.47766113, ...,  0.00250244,
#           0.00088501, -0.00061035]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([-0.02078247, -0.01861572, -0.00253296, ..., -0.00534058,
#          -0.00878906, -0.02420044]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([0.00064087, 0.00094604, 0.00064087, ..., 0.        , 0.        ,
#          0.        ]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([0.00000000e+00, 3.05175781e-05, 3.05175781e-05, ...,
#          5.95092773e-03, 9.39941406e-03, 9.06372070e-03]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([-9.15527344e-05, -6.10351562e-05,  1.83105469e-04, ...,
#          -2.13623047e-03, -2.44140625e-03, -1.55639648e-03]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([-3.66210938e-04, -6.10351562e-05,  0.00000000e+00, ...,
#          -2.05688477e-02, -3.77502441e-02, -1.20544434e-02]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([0.00048828, 0.00054932, 0.00048828, ..., 0.        , 0.        ,
#          0.        ]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([ 0.03768921,  0.04699707,  0.03759766, ..., -0.00836182,
#          -0.00524902, -0.00073242]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([-0.11862183, -0.11560059, -0.11361694, ...,  0.02935791,
#           0.03567505,  0.03683472]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([0.00115967, 0.00454712, 0.00622559, ..., 0.0112915 , 0.01101685,
#          0.01019287]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([-0.02624512, -0.03674316, -0.04562378, ...,  0.04376221,
#           0.0411377 ,  0.03085327]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([-0.26089478, -0.26428223, -0.26647949, ..., -0.07208252,
#          -0.06600952, -0.06176758]),
#   'sampling_rate': 44100},
#  {'path': None,
# ...
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([-0.12902832, -0.13119507, -0.11758423, ..., -0.15353394,
#          -0.15585327, -0.14416504]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([0.00820923, 0.02206421, 0.0368042 , ..., 0.07199097, 0.07495117,
#          0.07574463]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([-0.00375366, -0.00527954, -0.00695801, ..., -0.00836182,
#          -0.00979614, -0.00927734]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([0.04800415, 0.04946899, 0.05105591, ..., 0.06161499, 0.06124878,
#          0.05996704]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([-0.06777954, -0.0680542 , -0.06613159, ..., -0.48397827,
#          -0.48010254, -0.47714233]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([0.03369141, 0.05383301, 0.07214355, ..., 0.        , 0.        ,
#          0.        ]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([-0.00299072, -0.00360107, -0.00161743, ..., -0.00744629,
#          -0.01702881, -0.02206421]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([ 0.06158447,  0.0730896 ,  0.06237793, ..., -0.04763794,
#          -0.07199097, -0.0909729 ]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([0.79571533, 0.71990967, 0.37518311, ..., 0.        , 0.        ,
#          0.        ]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([-0.34158325, -0.36529541, -0.3765564 , ...,  0.01858521,
#           0.02029419,  0.0222168 ]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([-0.01242065, -0.01095581, -0.02111816, ..., -0.00396729,
#          -0.00177002,  0.02160645]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([-0.55853271,  0.75317383,  0.95718384, ..., -0.70452881,
#          -0.09597778,  0.75827026]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([-0.48901367, -0.17633057,  0.30291748, ..., -0.15118408,
#          -0.17202759,  0.00518799]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([0.00152588, 0.00158691, 0.00152588, ..., 0.        , 0.        ,
#          0.        ]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([0.01586914, 0.01913452, 0.03222656, ..., 0.        , 0.        ,
#          0.        ]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([-1.83105469e-04, -2.13623047e-04, -2.13623047e-04, ...,
#           3.05175781e-05,  3.05175781e-05,  9.15527344e-05]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([ 0.06948853,  0.09579468,  0.08511353, ..., -0.10205078,
#          -0.11697388, -0.09567261]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([0.01187134, 0.00854492, 0.0078125 , ..., 0.        , 0.        ,
#          0.        ]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([0.00012207, 0.00018311, 0.00021362, ..., 0.        , 0.        ,
#          0.        ]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([ 0.02545166,  0.02557373,  0.02642822, ..., -0.03479004,
#          -0.03048706, -0.03359985]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([-0.1434021 , -0.14382935, -0.14224243, ...,  0.0843811 ,
#           0.08633423,  0.08633423]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([-0.16491699, -0.15499878, -0.14871216, ...,  0.23251343,
#           0.22729492,  0.22332764]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([-0.03820801, -0.03372192, -0.02090454, ...,  0.00650024,
#           0.0010376 , -0.00231934]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([ 0.16165161,  0.16497803,  0.16802979, ..., -0.05218506,
#          -0.04367065, -0.03509521]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([-0.00866699, -0.01196289, -0.01934814, ..., -0.0144043 ,
#          -0.04025269, -0.05776978]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([ 0.00067139,  0.0020752 , -0.00024414, ..., -0.0062561 ,
#          -0.01959229, -0.03210449]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([0.03329468, 0.04522705, 0.03469849, ..., 0.        , 0.        ,
#          0.        ]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([0.00341797, 0.00369263, 0.01226807, ..., 0.30795288, 0.31622314,
#          0.33474731]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([0.06140137, 0.05300903, 0.0630188 , ..., 0.05480957, 0.10287476,
#          0.12539673]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([-0.02212524, -0.02954102, -0.02774048, ...,  0.        ,
#           0.        ,  0.        ]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([-0.20632935, -0.23794556, -0.20516968, ..., -0.09365845,
#          -0.08551025, -0.05249023]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([ 0.00363159, -0.01272583, -0.02941895, ..., -0.06335449,
#          -0.06298828, -0.06188965]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([0.24655151, 0.26483154, 0.27682495, ..., 0.41159058, 0.41116333,
#          0.40756226]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([-0.00683594, -0.00268555,  0.01751709, ...,  0.01205444,
#           0.01626587,  0.02832031]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([-0.2494812 , -0.29492188,  0.38671875, ...,  0.0050354 ,
#           0.00509644,  0.0050354 ]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([0.03100586, 0.03543091, 0.03735352, ..., 0.03701782, 0.03594971,
#          0.03613281]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([-0.02346802, -0.0222168 , -0.02114868, ..., -0.01724243,
#          -0.01663208, -0.01580811]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([-0.03237915, -0.03295898, -0.03237915, ...,  0.02386475,
#           0.01156616,  0.00170898]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([-0.02365112, -0.02120972, -0.01971436, ..., -0.00518799,
#          -0.00949097, -0.01135254]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([-9.15527344e-05, -6.10351562e-05, -3.05175781e-05, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([ 0.00131226,  0.00146484,  0.00140381, ..., -0.11123657,
#          -0.14260864, -0.11837769]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([0.00000000e+00, 3.05175781e-05, 0.00000000e+00, ...,
#          4.60418701e-01, 4.06799316e-01, 3.47686768e-01]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([-0.01748657, -0.02316284, -0.0241394 , ...,  0.04122925,
#           0.0428772 ,  0.03552246]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([-0.12710571, -0.13720703, -0.15432739, ...,  0.27163696,
#           0.26016235,  0.24755859]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([ 0.0012207 ,  0.00198364,  0.00198364, ..., -0.00036621,
#          -0.00018311, -0.00015259]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([-0.00823975, -0.01168823, -0.00939941, ..., -0.12033081,
#          -0.07177734, -0.03659058]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([0.01846313, 0.06253052, 0.06021118, ..., 0.05633545, 0.03115845,
#          0.00408936]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([-3.05175781e-05,  3.05175781e-05, -3.05175781e-05, ...,
#           4.15039062e-03,  4.91333008e-03,  4.63867188e-03]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([-0.01150513, -0.01446533, -0.01272583, ...,  0.00579834,
#           0.00579834,  0.00332642]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([0.00082397, 0.00112915, 0.00094604, ..., 0.        , 0.        ,
#          0.        ]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([-0
),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([ 3.05175781e-05, -3.05175781e-05, -3.05175781e-05, ...,
#          -8.74664307e-01, -9.73266602e-01, -7.64251709e-01]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([0.00015259, 0.00045776, 0.00064087, ..., 0.        , 0.        ,
#          0.        ]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([0., 0., 0., ..., 0., 0., 0.]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([-0.11227417, -0.08251953, -0.04418945, ...,  0.        ,
#           0.        ,  0.        ]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([0., 0., 0., ..., 0., 0., 0.]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([-9.15527344e-05,  0.00000000e+00, -3.05175781e-05, ...,
#          -7.01904297e-04,  1.83105469e-04,  3.05175781e-05]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([-0.01522827, -0.00985718, -0.00732422, ...,  0.        ,
#           0.        ,  0.        ]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([6.10351562e-05, 6.10351562e-05, 6.10351562e-05, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([-0.00515747, -0.00592041, -0.00479126, ..., -0.00012207,
#          -0.00045776, -0.00057983]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([-0.03521729, -0.04934692, -0.04296875, ...,  0.29556274,
#           0.28536987,  0.2902832 ]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([-0.01782227, -0.02416992, -0.02032471, ..., -0.11071777,
#          -0.13308716, -0.1083374 ]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([-0.059021  , -0.08450317, -0.09127808, ..., -0.02529907,
#          -0.03436279, -0.03048706]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([ 0.01947021, -0.02914429, -0.07119751, ..., -0.00726318,
#          -0.01174927, -0.0100708 ]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([-0.06677246, -0.10061646, -0.11383057, ...,  0.0039978 ,
#           0.00488281,  0.00354004]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([0.00045776, 0.00030518, 0.00021362, ..., 0.00265503, 0.00332642,
#          0.00231934]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([-0.05618286, -0.05630493, -0.05654907, ...,  0.        ,
#           0.        ,  0.        ]),
#   'sampling_rate': 44100},
#  {'path': None,
#   'array': array([0.00186157, 0.00189209, 0.00180054, ..., 0.00054932, 0.00036621,
#          0.00033569]),
#   'sampling_rate': 44100},
#  ...]

# %%
audio = next(iter(dataset["train"]["audio"]))["array"]
classifier(audio, candidate_labels=["Sound of a dog", "Sound of vaccum cleaner"])
# Out:
# [{'score': 0.9995999932289124, 'label': 'Sound of a dog'},
#  {'score': 0.0004000737681053579, 'label': 'Sound of vaccum cleaner'}]

# %%
sd.play(audio)

# %% [markdown]
# https://huggingface.co/datasets/ashraq/esc50

# %% [markdown]
# <br />  <font size="+2">4. Emotion Recognition</font> <br /> <br />

# %%
import requests

API_TOKEN = "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"
API_URL = "https://api-inference.huggingface.co/models/harshit345/xlsr-wav2vec-speech-emotion-recognition"
headers = {"Authorization": f"Bearer {API_TOKEN}"}


def query(filename):
    with open(filename, "rb") as f:
        data = f.read()
    response = requests.post(API_URL, headers=headers, data=data)
    return response.json()


dataset = load_dataset("anton-l/superb_demo", "ks", split="test")

output = query(dataset[1]["file"])

output
# Out:
# Found cached dataset superb_demo (/Users/sridharkannam/.cache/huggingface/datasets/anton-l___superb_demo/ks/1.9.0/77d23894ff429329a7fe80f9007cabb0deec321316f8dda1a1e9d10ffa089d08)
# [{'score': 0.21224874258041382, 'label': 'happiness'},
#  {'score': 0.20905514061450958, 'label': 'sadness'},
#  {'score': 0.19708998501300812, 'label': 'disgust'},
#  {'score': 0.19202306866645813, 'label': 'fear'},
#  {'score': 0.18958303332328796, 'label': 'anger'}]

# %%
# Extract data and sampling rate from file
data, fs = sf.read(dataset[1]["file"], dtype="float32")
sd.play(data, fs)
